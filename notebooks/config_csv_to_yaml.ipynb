# %%
import pandas as pd
import yaml, json
import os
df = pd.read_csv('../example/configs/cdap_2_person.csv').transpose()
df.columns = df.columns.astype('str')
d = df.to_dict().values()
stream = yaml.safe_dump(d, default_flow_style = False)
print stream.replace('\n- ', '\n\n- ')
# Out:
# - Description: Non-working adult interaction with pre-driving-age child who is in
#     school
#   Expression: ptype == 47 or ptype == 74
#   Home: 0.8112
#   Mandatory: .nan
#   NonMandatory: 0.5646
#
# - Description: Non-working adult interaction with pre-driving-age child who is too
#     young for school
#   Expression: ptype == 48 or ptype == 84
#   Home: 1.167
#   Mandatory: .nan
#   NonMandatory: 1.1640000000000001
#
# - Description: Retired interaction with retired
#   Expression: ptype == 55
#   Home: 1.4069999999999998
#   Mandatory: .nan
#   NonMandatory: 0.7291
#
# - Description: Retired interaction with driving-age child who is in school
#   Expression: ptype == 56 or ptype == 65
#   Home: 0.8632
#   Mandatory: .nan
#   NonMandatory: 0.2919
#
# - Description: University student interaction with pre-driving-age child who is too
#     young for school
#   Expression: ptype == 38 or ptype == 83
#   Home: 1.34
#   Mandatory: 0.2254
#   NonMandatory: 0.8973
#
# ...
